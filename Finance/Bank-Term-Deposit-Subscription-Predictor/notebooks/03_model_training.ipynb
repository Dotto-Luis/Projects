# %% [markdown]
# ## 1. Introduction
# ## 2. Objective
# ## 3. Data Loading
# ## 4. Train-Test Split
# ## 5. Baseline Model
# ## 6. Model Selection
# ## 7. Model Training
# ## 8. Hyperparameter Tuning (Optional)
# ## 9. Model Comparison
# ## 10. Selected Model
